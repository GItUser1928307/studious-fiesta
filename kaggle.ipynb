# %%
# !torchrun --nproc_per_node=2 retrain.py
# Out:
# W0707 12:25:16.460000 482 torch/distributed/run.py:852]
# W0707 12:25:16.460000 482 torch/distributed/run.py:852] *****************************************
# W0707 12:25:16.460000 482 torch/distributed/run.py:852] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# W0707 12:25:16.460000 482 torch/distributed/run.py:852] *****************************************
# GPUs detected: 2
#   GPU 0: Tesla T4
#   GPU 1: Tesla T4
# Using DDP across 2 GPUs — each GPU runs its own process
# Tokenizer: word
# Vocab size: 46369
# Vocab size: 46369
#   Special: ['<pad>', '<bos>', '<eos>', '<unk>', '<q>', '<a>']
#   Words: 46363
# Params: 56,239,104
# Config: hidden=384, layers=21, seq=96, vocab=46369
# Device: cuda:0
# Dataset: 1003 samples, 16 batches
# Saved checkpoint at step 200
# Saved checkpoint at step 400
# ...
